# %%
import duckdb
import pandas as pd

# %%
con = duckdb.connect(database='../data/nba.sqlite', read_only=False)
df = con.query("show tables").fetchdf()
df
# Out:
#                    name
# 0    common_player_info
# 1   draft_combine_stats
# 2         draft_history
# 3                  game
# 4             game_info
# 5          game_summary
# 6      inactive_players
# 7            line_score
# 8             officials
# 9           other_stats
# 10         play_by_play
# 11               player
# 12                 team
# 13         team_details
# 14         team_history
# 15     team_info_common

# %%
## get game-ids

df = con.query("select * from play_by_play limit 2").fetchdf()
df
# Out:
#       game_id  eventnum  eventmsgtype  eventmsgactiontype  period  \
# 0  0029600012         0            12                   0       1
# 1  0029600012         2            10                   0       1
#
#   wctimestring pctimestring                              homedescription  \
# 0     14:43 PM        12:00                                         None
# 1     14:50 PM        12:00  Jump Ball O'Neal vs. Kleine: Tip to Cassell
#
#                    neutraldescription visitordescription  ...  \
# 0  Start of 1st Period (14:43 PM EST)               None  ...
# 1                                None               None  ...
#
#   player2_team_nickname player2_team_abbreviation  person3type player3_id  \
# 0                  None                      None          0.0          0
# 1                  Suns                       PHX          5.0        208
#
#   player3_name player3_team_id player3_team_city player3_team_nickname  \
# 0         None            None              None                  None
# 1  Sam Cassell    1610612756.0           Phoenix                  Suns
#
#   player3_team_abbreviation  video_available_flag
# 0                      None                     0
# 1                       PHX                     0
#
# [2 rows x 34 columns]

# %%
df = con.query("select * from play_by_play where game_id = '0029600012'").fetchdf()

# %%
df.head(30)
# Out:
#        game_id  eventnum  eventmsgtype  eventmsgactiontype  period  \
# 0   0029600012         0            12                   0       1
# 1   0029600012         2            10                   0       1
# 2   0029600012         3             2                   1       1
# 3   0029600012         4             4                   0       1
# 4   0029600012         5             2                   1       1
# 5   0029600012         6             4                   0       1
# 6   0029600012         7             6                   1       1
# 7   0029600012         8             5                   1       1
# 8   0029600012         9             2                   5       1
# 9   0029600012        10             4                   0       1
# 10  0029600012        11             5                   2       1
# 11  0029600012        12             5                   1       1
# 12  0029600012        13             1                   8       1
# 13  0029600012        14             2                   1       1
# 14  0029600012        15             4                   0       1
# 15  0029600012        16             1                   5       1
# 16  0029600012        17             2                   1       1
# 17  0029600012        18             4                   0       1
# 18  0029600012        19             2                   1       1
# 19  0029600012        20             4                   0       1
# 20  0029600012        21             5                   1       1
# 21  0029600012        22             6                   2       1
# 22  0029600012        24             3                  11       1
# 23  0029600012        25             8                   0       1
# 24  0029600012        26             3                  12       1
# 25  0029600012        27             2                   5       1
# 26  0029600012        28             4                   0       1
# 27  0029600012        30             7                   3       1
# 28  0029600012        29             1                   5       1
# 29  0029600012        31             6                   2       1
#
#    wctimestring pctimestring                              homedescription  \
# 0      14:43 PM        12:00                                         None
# 1      14:50 PM        12:00  Jump Ball O'Neal vs. Kleine: Tip to Cassell
# 2      14:51 PM        11:45                                         None
# 3      14:51 PM        11:43                 O'Neal REBOUND (Off:0 Def:1)
# 4      14:51 PM        11:29              MISS Ceballos 26' 3PT Jump Shot
# 5      14:51 PM        11:27                                         None
# 6      14:51 PM        11:14                      Van Exel P.FOUL (P1.T1)
# 7      14:52 PM        11:08                                         None
# 8      14:52 PM        10:49                       MISS Ceballos 1' Layup
# 9      14:52 PM        10:49                               LAKERS Rebound
# 10     14:52 PM        10:45          Ceballos Lost Ball Turnover (P1.T1)
# 11     14:52 PM        10:42                       Van Exel STEAL (1 STL)
# 12     14:53 PM        10:40   O'Neal  Slam Dunk (2 PTS) (Van Exel 1 AST)
# 13     14:53 PM        10:19                                         None
# 14     14:53 PM        10:18               Ceballos REBOUND (Off:0 Def:1)
# 15     14:53 PM        10:05        Ceballos  Layup (2 PTS) (Jones 1 AST)
# 16     14:53 PM         9:42                                         None
# 17     14:53 PM         9:40                                         None
# 18     14:54 PM         9:38                                         None
# 19     14:54 PM         9:36                 O'Neal REBOUND (Off:0 Def:2)
# 20     14:54 PM         9:32           Ceballos Bad Pass Turnover (P2.T2)
# 21     14:54 PM         9:24                      Van Exel S.FOUL (P2.T2)
# 22     14:54 PM         9:24                                         None
# 23     14:54 PM         9:24                     SUB: Fisher FOR Van Exel
# 24     14:54 PM         9:24                                         None
# 25     14:55 PM         9:13                         MISS Ceballos  Layup
# 26     14:55 PM         9:11                                         None
# 27     14:55 PM         8:53                         Jones Violation:Lane
# 28     14:55 PM         8:53                                         None
# 29     14:56 PM         8:37                                         None
#
#                     neutraldescription                    visitordescription  \
# 0   Start of 1st Period (14:43 PM EST)                                  None
# 1                                 None                                  None
# 2                                 None            MISS Cassell 15' Jump Shot
# 3                                 None                                  None
# 4                                 None                                  None
# 5                                 None         Cassell REBOUND (Off:0 Def:1)
# 6                                 None                                  None
# 7                                 None     Cassell Bad Pass Turnover (P1.T1)
# 8                                 None                   Horry BLOCK (1 BLK)
# 9                                 None                                  None
# 10                                None                   Horry STEAL (1 STL)
# 11                                None       Horry Bad Pass Turnover (P1.T2)
# 12                                None                                  None
# 13                                None             MISS Kleine 11' Jump Shot
# 14                                None                                  None
# 15                                None                                  None
# 16                                None             MISS Person 16' Jump Shot
# 17                                None          Kleine REBOUND (Off:1 Def:0)
# 18                                None            MISS Person  3PT Jump Shot
# 19                                None                                  None
# 20                                None                   Green STEAL (1 STL)
# 21                                None                                  None
# 22                                None     Cassell Free Throw 1 of 2 (1 PTS)
# 23                                None                                  None
# 24                                None     Cassell Free Throw 2 of 2 (2 PTS)
# 25                                None                   Green BLOCK (1 BLK)
# 26                                None                          Suns Rebound
# 27                                None                                  None
# 28                                None  Person  Layup (2 PTS) (Kleine 1 AST)
# 29                                None                 Kleine S.FOUL (P1.T1)
#
#     ... player2_team_nickname player2_team_abbreviation  person3type  \
# 0   ...                  None                      None          0.0
# 1   ...                  Suns                       PHX          5.0
# 2   ...                  None                      None          0.0
# 3   ...                  None                      None          0.0
# 4   ...                  None                      None          0.0
# 5   ...                  None                      None          0.0
# 6   ...                  None                      None          0.0
# 7   ...                  None                      None          0.0
# 8   ...                  None                      None          5.0
# 9   ...                  None                      None          0.0
# 10  ...                  Suns                       PHX          0.0
# 11  ...                Lakers                       LAL          0.0
# 12  ...                Lakers                       LAL          0.0
# 13  ...                  None                      None          0.0
# 14  ...                  None                      None          0.0
# 15  ...                Lakers                       LAL          0.0
# 16  ...                  None                      None          0.0
# 17  ...                  None                      None          0.0
# 18  ...                  None                      None          0.0
# 19  ...                  None                      None          0.0
# 20  ...                  Suns                       PHX          0.0
# 21  ...                  None                      None          0.0
# 22  ...                  None                      None          0.0
# 23  ...                Lakers                       LAL          0.0
# 24  ...                  None                      None          0.0
# 25  ...                  None                      None          5.0
# 26  ...                  None                      None          0.0
# 27  ...                  None                      None          0.0
# 28  ...                  Suns                       PHX          4.0
# 29  ...                  Suns                       PHX          0.0
#
#    player3_id  player3_name player3_team_id player3_team_city  \
# 0           0          None            None              None
# 1         208   Sam Cassell    1610612756.0           Phoenix
# 2           0          None            None              None
# 3           0          None            None              None
# 4           0          None            None              None
# 5           0          None            None              None
# 6           0          None            None              None
# 7           0          None            None              None
# 8         109  Robert Horry    1610612756.0           Phoenix
# 9           0          None            None              None
# 10          0          None            None              None
# 11          0          None            None              None
# 12          0          None            None              None
# 13          0          None            None              None
# 14          0          None            None              None
# 15          0          None            None              None
# 16          0          None            None              None
# 17          0          None            None              None
# 18          0          None            None              None
# 19          0          None            None              None
# 20          0          None            None              None
# 21          0          None            None              None
# 22          0          None            None              None
# 23          0          None            None              None
# 24          0          None            None              None
# 25        920    A.C. Green    1610612756.0           Phoenix
# 26          0          None            None              None
# 27          0          None            None              None
# 28          0          None    1610612747.0       Los Angeles
# 29          0          None            None              None
#
#    player3_team_nickname player3_team_abbreviation  video_available_flag
# 0                   None                      None                     0
# 1                   Suns                       PHX                     0
# 2                   None                      None                     0
# 3                   None                      None                     0
# 4                   None                      None                     0
# 5                   None                      None                     0
# 6                   None                      None                     0
# 7                   None                      None                     0
# 8                   Suns                       PHX                     0
# 9                   None                      None                     0
# 10                  None                      None                     0
# 11                  None                      None                     0
# 12                  None                      None                     0
# 13                  None                      None                     0
# 14                  None                      None                     0
# 15                  None                      None                     0
# 16                  None                      None                     0
# 17                  None                      None                     0
# 18                  None                      None                     0
# 19                  None                      None                     0
# 20                  None                      None                     0
# 21                  None                      None                     0
# 22                  None                      None                     0
# 23                  None                      None                     0
# 24                  None                      None                     0
# 25                  Suns                       PHX                     0
# 26                  None                      None                     0
# 27                  None                      None                     0
# 28                Lakers                       LAL                     0
# 29                  None                      None                     0
#
# [30 rows x 34 columns]

# %%
df[["homedescription",	"neutraldescription"	,"visitordescription"]]
# Out:
#                                  homedescription  \
# 0                                           None
# 1    Jump Ball O'Neal vs. Kleine: Tip to Cassell
# 2                                           None
# 3                   O'Neal REBOUND (Off:0 Def:1)
# 4                MISS Ceballos 26' 3PT Jump Shot
# ..                                           ...
# 461                                         None
# 462                                         None
# 463                                         None
# 464                 Knight REBOUND (Off:0 Def:2)
# 465                                         None
#
#                      neutraldescription              visitordescription
# 0    Start of 1st Period (14:43 PM EST)                            None
# 1                                  None                            None
# 2                                  None      MISS Cassell 15' Jump Shot
# 3                                  None                            None
# 4                                  None                            None
# ..                                  ...                             ...
# 461                                None  MISS Manning Free Throw 1 of 2
# 462                                None                    Suns Rebound
# 463                                None  MISS Manning Free Throw 2 of 2
# 464                                None                            None
# 465    End of 4th Period (17:12 PM EST)                            None
#
# [466 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['game_id', 'eventnum', 'eventmsgtype', 'eventmsgactiontype', 'period',
#        'wctimestring', 'pctimestring', 'homedescription', 'neutraldescription',
#        'visitordescription', 'score', 'scoremargin', 'person1type',
#        'player1_id', 'player1_name', 'player1_team_id', 'player1_team_city',
#        'player1_team_nickname', 'player1_team_abbreviation', 'person2type',
#        'player2_id', 'player2_name', 'player2_team_id', 'player2_team_city',
#        'player2_team_nickname', 'player2_team_abbreviation', 'person3type',
#        'player3_id', 'player3_name', 'player3_team_id', 'player3_team_city',
#        'player3_team_nickname', 'player3_team_abbreviation',
#        'video_available_flag'],
#       dtype='object')

# %%
## Pseudo logic for aggregation of player counting stats


# from collections import Counter

# players = Counter()

# for game in games:
#     for event in game.events:
#         player = event.player
#         stat = event.stat
#         players[player[stat]] += 1
