# %%
import duckdb
import pandas as pd

# %%
con = duckdb.connect(database='../data/nba.sqlite', read_only=False)
df = con.query("show tables").fetchdf()
df
# Out:
#                    name
# 0    common_player_info
# 1   draft_combine_stats
# 2         draft_history
# 3                  game
# 4             game_info
# 5          game_summary
# 6      inactive_players
# 7            line_score
# 8             officials
# 9           other_stats
# 10         play_by_play
# 11               player
# 12                 team
# 13         team_details
# 14         team_history
# 15     team_info_common

# %%
## get game-ids

df = con.query("select * from play_by_play limit 500").fetchdf()
df['game_id'].unique()
# Out:
# array(['0029600012', '0029600005'], dtype=object)

# %%
df = con.query("select * from play_by_play where game_id = '0029600005'").fetchdf()

# %%
df.head(30)
# Out:
#        game_id  eventnum  eventmsgtype  eventmsgactiontype  period  \
# 0   0029600005         1            10                   0       1
# 1   0029600005         2             6                   1       1
# 2   0029600005         3            10                   0       1
# 3   0029600005         4             2                   1       1
# 4   0029600005         5             4                   0       1
# 5   0029600005         6             1                   1       1
# 6   0029600005         7             1                   6       1
# 7   0029600005         8             1                   1       1
# 8   0029600005         9             2                   1       1
# 9   0029600005        10             4                   0       1
# 10  0029600005        11             2                   3       1
# 11  0029600005        12             4                   0       1
# 12  0029600005        13             5                   2       1
# ...

# %%
df.columns
# Out:
# Index(['game_id', 'eventnum', 'eventmsgtype', 'eventmsgactiontype', 'period',
#        'wctimestring', 'pctimestring', 'homedescription', 'neutraldescription',
#        'visitordescription', 'score', 'scoremargin', 'person1type',
#        'player1_id', 'player1_name', 'player1_team_id', 'player1_team_city',
#        'player1_team_nickname', 'player1_team_abbreviation', 'person2type',
#        'player2_id', 'player2_name', 'player2_team_id', 'player2_team_city',
#        'player2_team_nickname', 'player2_team_abbreviation', 'person3type',
#        'player3_id', 'player3_name', 'player3_team_id', 'player3_team_city',
#        'player3_team_nickname', 'player3_team_abbreviation',
#        'video_available_flag'],
#       dtype='object')

# %%
df[[ 'eventnum', 'eventmsgtype', 'eventmsgactiontype',
        'homedescription', 'neutraldescription',
       'visitordescription',  'player1_id', 'player1_name', 'player1_team_id',
       'person2type',
       'player2_id', 'player2_name', 'player2_team_id', 
       'person3type',
       'player3_id', 'player3_name', 'player3_team_id', 
        'player3_team_abbreviation',
    ]].head(5)
# Out:
#    eventnum  eventmsgtype  eventmsgactiontype  \
# 0         1            10                   0
# 1         2             6                   1
# 2         3            10                   0
# 3         4             2                   1
# 4         5             4                   0
#
#                                     homedescription neutraldescription  \
# 0   Jump Ball Mourning vs. Mutombo: Tip to Mourning               None
# 1                                              None               None
# 2  Jump Ball Mourning vs. Blaylock: Tip to Hardaway               None
# 3                          MISS Thomas 9' Jump Shot               None
# 4                   Danilovic REBOUND (Off:1 Def:0)               None
#
#       visitordescription player1_id     player1_name player1_team_id  \
# 0                   None        297  Alonzo Mourning    1610612748.0
# 1  Corbin P.FOUL (P1.T1)        895    Tyrone Corbin    1610612737.0
# ...

# %%
df[["homedescription",	"neutraldescription"	,"visitordescription"]]
# Out:
#                                       homedescription  \
# 0     Jump Ball Mourning vs. Mutombo: Tip to Mourning
# 1                                                None
# 2    Jump Ball Mourning vs. Blaylock: Tip to Hardaway
# 3                            MISS Thomas 9' Jump Shot
# 4                     Danilovic REBOUND (Off:1 Def:0)
# ..                                                ...
# 435                Majerle Free Throw 2 of 2 (14 PTS)
# 436                            Hardaway STEAL (3 STL)
# 437                    MISS Majerle 24' 3PT Jump Shot
# 438                                              None
# 439                                              None
#
#                    neutraldescription                   visitordescription
# 0                                None                                 None
# 1                                None                Corbin P.FOUL (P1.T1)
# 2                                None                                 None
# ...

# %%
df.columns
# Out:
# Index(['game_id', 'eventnum', 'eventmsgtype', 'eventmsgactiontype', 'period',
#        'wctimestring', 'pctimestring', 'homedescription', 'neutraldescription',
#        'visitordescription', 'score', 'scoremargin', 'person1type',
#        'player1_id', 'player1_name', 'player1_team_id', 'player1_team_city',
#        'player1_team_nickname', 'player1_team_abbreviation', 'person2type',
#        'player2_id', 'player2_name', 'player2_team_id', 'player2_team_city',
#        'player2_team_nickname', 'player2_team_abbreviation', 'person3type',
#        'player3_id', 'player3_name', 'player3_team_id', 'player3_team_city',
#        'player3_team_nickname', 'player3_team_abbreviation',
#        'video_available_flag'],
#       dtype='object')

# %%
## Pseudo logic for aggregation of player counting stats


# from collections import Counter

# players = Counter()

# for game in games:
#     for event in game.events:
#         player = event.player
#         stat = event.stat
#         players[player[stat]] += 1
