# %%
from nba_api.stats.static import teams
from nba_api.stats.endpoints import leaguegamefinder
import pandas as pd

# %%
teams_info = teams.get_teams()
teams_df = pd.DataFrame(teams_info)
teams_df.head()
# Out:
#            id             full_name abbreviation   nickname         city  \
# 0  1610612737         Atlanta Hawks          ATL      Hawks      Atlanta
# 1  1610612738        Boston Celtics          BOS    Celtics       Boston
# 2  1610612739   Cleveland Cavaliers          CLE  Cavaliers    Cleveland
# 3  1610612740  New Orleans Pelicans          NOP   Pelicans  New Orleans
# 4  1610612741         Chicago Bulls          CHI      Bulls      Chicago
#
#            state  year_founded
# 0        Georgia          1949
# 1  Massachusetts          1946
# 2           Ohio          1970
# 3      Louisiana          2002
# 4       Illinois          1966

# %%
gamefinder = leaguegamefinder.LeagueGameFinder(season_nullable='2014')
games = gamefinder.get_data_frames()
print(games[0].iloc[0])
# Out:
# Index(['SEASON_ID', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_NAME', 'GAME_ID',
#        'GAME_DATE', 'MATCHUP', 'WL', 'MIN', 'PTS', 'FGM', 'FGA', 'FG_PCT',
#        'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB',
#        'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PLUS_MINUS'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['PLAYER_ID', 'SEASON_ID', 'LEAGUE_ID', 'TEAM_ID', 'TEAM_ABBREVIATION',
#        'PLAYER_AGE', 'GP', 'GS', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A',
#        'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL',
#        'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df['expected_min'] = df['MIN'] / df['GP']
df
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0         252   1985-86        00  1610612762               UTH        22.0
# 1         252   1986-87        00  1610612762               UTH        23.0
# 2         252   1987-88        00  1610612762               UTH        24.0
# 3         252   1988-89        00  1610612762               UTH        25.0
# 4         252   1989-90        00  1610612762               UTH        26.0
# 5         252   1990-91        00  1610612762               UTH        27.0
# 6         252   1991-92        00  1610612762               UTH        28.0
# 7         252   1992-93        00  1610612762               UTH        29.0
# 8         252   1993-94        00  1610612762               UTH        30.0
# 9         252   1994-95        00  1610612762               UTH        31.0
# 10        252   1995-96        00  1610612762               UTH        32.0
# ...

# %%
df['expected_ast'] = df['AST'] / df['MIN']
df
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0         252   1985-86        00  1610612762               UTH        22.0
# 1         252   1986-87        00  1610612762               UTH        23.0
# 2         252   1987-88        00  1610612762               UTH        24.0
# 3         252   1988-89        00  1610612762               UTH        25.0
# 4         252   1989-90        00  1610612762               UTH        26.0
# 5         252   1990-91        00  1610612762               UTH        27.0
# 6         252   1991-92        00  1610612762               UTH        28.0
# 7         252   1992-93        00  1610612762               UTH        29.0
# 8         252   1993-94        00  1610612762               UTH        30.0
# 9         252   1994-95        00  1610612762               UTH        31.0
# 10        252   1995-96        00  1610612762               UTH        32.0
# ...

# %% [markdown]
# - combine offensive and defensive into mean?
# - use
